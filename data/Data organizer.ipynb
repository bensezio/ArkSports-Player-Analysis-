# %%
import pandas as pd

# %%
df = pd.read_csv('Test_1.csv')

# %%
df.head()
# Out:
#               Player Position_Cleaned   Age  Born Nation  MP  Starts   Min  \
# 0   Brenden Aaronson               AM  22.0  2000    USA  20      19  1596
# 1      Himad Abdelli               AM  23.0  1999    FRA  14       8   770
# 2  Salis Abdul Samed               MF  22.0  2000    GHA  20      20  1799
# 3    Laurent Abergel               MF  30.0  1993    FRA  15      15  1165
# 4  Oliver Abildgaard               MF  26.0  1996    DEN   1       0    11
#
#     90s  Goals  ...  Recov  PKwon  PKcon  TouDef3rd_norm  TouMid3rd_norm  \
# 0  17.7      1  ...   4.86    0.0    0.0        0.098864        0.431818
# 1   8.6      0  ...   8.14    0.0    0.0        0.182109        0.575080
# 2  20.0      1  ...   6.60    0.0    0.0        0.163711        0.676671
# 3  12.9      0  ...   6.51    0.0    0.0        0.351005        0.574040
# 4   0.1      0  ...  10.00    0.0    0.0        0.400000        0.400000
#
#    TouAtt3rd_norm  TouDefPen_norm  TouAttPen_norm  grid_x  grid_y
# ...
